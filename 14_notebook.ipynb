# %% [markdown]
# <a href="https://colab.research.google.com/github/Uriel1201/HelloSQL/blob/main/14_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/Uriel1201/HelloSQL/main/functions_df.py
# Out:
# --2024-06-06 20:11:01--  https://raw.githubusercontent.com/Uriel1201/HelloSQL/main/functions_df.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3361 (3.3K) [text/plain]
# Saving to: ‘functions_df.py’
#
# functions_df.py     100%[===================>]   3.28K  --.-KB/s    in 0s
#
# 2024-06-06 20:11:01 (45.7 MB/s) - ‘functions_df.py’ saved [3361/3361]

# %%
import pandas as pd
import numpy  as np
import functions_df as fdf

data = {'id'        : [1,2,1,2,3,1,3,1,3],
        'pay_month' : [1,1,2,2,2,3,3,4,4],
        'salary'    : [20,20,30,30,40,40,60,60,70]
        }

employee = pd.DataFrame(data)

# %%
employee.sort_values(by = ['id', 'pay_month'], inplace = True)

# %%
employee
# Out:
#    id  pay_month  salary
# 0   1          1      20
# 2   1          2      30
# 5   1          3      40
# 7   1          4      60
# 1   2          1      20
# 3   2          2      30
# 4   3          2      40
# 6   3          3      60
# 8   3          4      70

# %%
employee['rank'] = employee.groupby('id')['pay_month'].transform(fdf.desc_row_num)

# %%
employee
# Out:
#    id  pay_month  salary  rank
# 0   1          1      20     4
# 2   1          2      30     3
# 5   1          3      40     2
# 7   1          4      60     1
# 1   2          1      20     2
# 3   2          2      30     1
# 4   3          2      40     3
# 6   3          3      60     2
# 8   3          4      70     1

# %%
no_last_month = employee[['id', 'salary']][employee['rank'] > 1]

# %%
no_last_month
# Out:
#    id  salary
# 0   1      20
# 2   1      30
# 5   1      40
# 1   2      20
# 4   3      40
# 6   3      60

# %%
cumm_salary = fdf.basic_cummulative(no_last_month, 'id', 'salary')

# %%
cumm_salary
# Out:
#    id_1  id_2   id_3
# 0  20.0  20.0   40.0
# 1  50.0  20.0  100.0
# 2  90.0  20.0  100.0

# %%
cumm_salary.iloc[-1]
# Out:
# id_1     90.0
# id_2     20.0
# id_3    100.0
# Name: 2, dtype: float64
