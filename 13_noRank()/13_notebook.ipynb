# %% [markdown]
# <a href="https://colab.research.google.com/github/Uriel1201/HelloSQL/blob/main/13_noRank()/13_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/Uriel1201/HelloSQL/main/functions_df.py
# Out:
# --2024-05-11 19:59:38--  https://raw.githubusercontent.com/Uriel1201/HelloSQL/main/functions_df.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1662 (1.6K) [text/plain]
# Saving to: ‘functions_df.py’
#
# functions_df.py     100%[===================>]   1.62K  --.-KB/s    in 0s
#
# 2024-05-11 19:59:38 (24.9 MB/s) - ‘functions_df.py’ saved [1662/1662]

# %% [markdown]
# # 13. Rank without RANK (hard)
# Write a query to rank scores in the following table without using a window function. If there is a tie between two scores, both should have the same rank. After a tie, the following rank should be the next consecutive integer value.

# %%
import pandas as pd
import numpy  as np
import functions_df as fd

data = {'id'    : [1,2,3,4,5,6],
        'score' : [3.5,3.65,4.0,3.85,4.0,3.65]
       }

scores = pd.DataFrame(data)

# %%
scores
# Out:
#    id  score
# 0   1   3.50
# 1   2   3.65
# 2   3   4.00
# 3   4   3.85
# 4   5   4.00
# 5   6   3.65

# %%
score_array = np.array(scores['score'])

# %% [markdown]
# Using my own rank_serie method to asign ranks on an array.

# %%
rank_df = pd.DataFrame(fd.rank_serie(score_array), columns = ['score', 'rank'])

# %%
rank_df.sort_values(by = 'rank')
# Out:
#    score  rank
# 2   4.00   1.0
# 4   4.00   1.0
# 3   3.85   2.0
# 1   3.65   3.0
# 5   3.65   3.0
# 0   3.50   4.0
