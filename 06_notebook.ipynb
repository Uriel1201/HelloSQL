# %% [markdown]
# <a href="https://colab.research.google.com/github/Uriel1201/HelloSQL/blob/main/06_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #06. Content recommendation (hard)
# Using the following two tables, write a query to return page recommendations to a social media user based on the pages that their friends have liked, but that they have not yet marked as liked. Order the result by ascending user ID.

# %%
import pandas as pd
import numpy  as np

data1 = {'user_id': [1,1,1,2,3,3,4,4],
         'friend'  : [2,3,4,1,1,4,1,3]
        }

data2 = {'user_id' : [1,1,1,2,3,3,4],
         'page_likes' : ['A','B','C','A','B','C','B']
        }

friends = pd.DataFrame(data1)
likes   = pd.DataFrame(data2)

# %%
friends
# Out:
#    user_id  friend
# 0        1       2
# 1        1       3
# 2        1       4
# 3        2       1
# 4        3       1
# 5        3       4
# 6        4       1
# 7        4       3

# %%
likes
# Out:
#    user_id page_likes
# 0        1          A
# 1        1          B
# 2        1          C
# 3        2          A
# 4        3          B
# 5        3          C
# 6        4          B

# %%
friends_likes = pd.merge(friends, likes, left_on = 'friend', right_on = 'user_id')

# %%
friends_likes
# Out:
#     user_id_x  friend  user_id_y page_likes
# 0           1       2          2          A
# 1           1       3          3          B
# 2           1       3          3          C
# 3           4       3          3          B
# 4           4       3          3          C
# 5           1       4          4          B
# 6           3       4          4          B
# 7           2       1          1          A
# 8           2       1          1          B
# 9           2       1          1          C
# 10          3       1          1          A
# 11          3       1          1          B
# 12          3       1          1          C
# 13          4       1          1          A
# 14          4       1          1          B
# 15          4       1          1          C

# %%
friends_likes.drop('user_id_y', axis = 1, inplace = True)
friends_likes.rename(columns = {'user_id_x' : 'user_id', 'page_likes' : 'friend_page_likes'}, inplace = True)

# %%
friends_likes
# Out:
#     user_id  friend friend_page_likes
# 0         1       2                 A
# 1         1       3                 B
# 2         1       3                 C
# 3         4       3                 B
# 4         4       3                 C
# 5         1       4                 B
# 6         3       4                 B
# 7         2       1                 A
# 8         2       1                 B
# 9         2       1                 C
# 10        3       1                 A
# 11        3       1                 B
# 12        3       1                 C
# 13        4       1                 A
# 14        4       1                 B
# 15        4       1                 C

# %%
friends_likes.set_index(['user_id', 'friend_page_likes'], inplace = True, drop = False)
user_likes = likes.set_index(['user_id', 'page_likes'], drop = False)

# %%
friends_likes.rename_axis(index = {'friend_page_likes' : 'page_likes'}, inplace = True)

# %%
friends_likes
# Out:
#                     user_id  friend friend_page_likes
# user_id page_likes
# 1       A                 1       2                 A
#         B                 1       3                 B
#         C                 1       3                 C
# 4       B                 4       3                 B
#         C                 4       3                 C
# 1       B                 1       4                 B
# 3       B                 3       4                 B
# 2       A                 2       1                 A
#         B                 2       1                 B
#         C                 2       1                 C
# 3       A                 3       1                 A
#         B                 3       1                 B
#         C                 3       1                 C
# 4       A                 4       1                 A
#         B                 4       1                 B
#         C                 4       1                 C

# %%
user_likes
# Out:
#                     user_id page_likes
# user_id page_likes
# 1       A                 1          A
#         B                 1          B
#         C                 1          C
# 2       A                 2          A
# 3       B                 3          B
#         C                 3          C
# 4       B                 4          B

# %%
user_likes.drop('user_id', axis = 1, inplace = True)

# %%
user_likes
# Out:
#                    page_likes
# user_id page_likes
# 1       A                   A
#         B                   B
#         C                   C
# 2       A                   A
# 3       B                   B
#         C                   C
# 4       B                   B

# %%
is_liked = pd.concat([friends_likes, user_likes], axis = 1, join = 'outer')

# %%
is_liked
# Out:
#                     user_id  friend friend_page_likes page_likes
# user_id page_likes
# 1       A                 1       2                 A          A
#         B                 1       3                 B          B
#         C                 1       3                 C          C
# 4       B                 4       3                 B          B
#         C                 4       3                 C        NaN
# 1       B                 1       4                 B          B
# 3       B                 3       4                 B          B
# 2       A                 2       1                 A          A
#         B                 2       1                 B        NaN
#         C                 2       1                 C        NaN
# 3       A                 3       1                 A        NaN
#         B                 3       1                 B          B
#         C                 3       1                 C          C
# 4       A                 4       1                 A        NaN
#         B                 4       1                 B          B
#         C                 4       1                 C        NaN

# %%
recomendations = is_liked[['user_id']][is_liked['page_likes'].isnull()]

# %%
recomendations.drop('user_id', axis = 1,inplace = True)
recomendations.reset_index(inplace = True)

# %%
recomendations.rename(columns = {'page_likes' : 'recommended_page'}, inplace = True)
recomendations.drop_duplicates(inplace = True)

# %%
recomendations.sort_values(by = 'user_id')
# Out:
#    user_id recommended_page
# 1        2                B
# 2        2                C
# 3        3                A
# 0        4                C
# 4        4                A
