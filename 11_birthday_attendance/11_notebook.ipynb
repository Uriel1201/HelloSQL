# %% [markdown]
# <a href="https://colab.research.google.com/github/Uriel1201/HelloSQL/blob/main/11_birthday_attendance/11_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #11. Birthday attendance
# Given the following two tables, write a query to return the fraction of students, rounded to two decimal places, who attended school  (attendance = 1) on their birthday.

# %%
import pandas as pd
import numpy  as np

data1 = {'student_id'    : [1,2,3,1,2,3,1,2,3,4],
        'school_date'    : ['03-APR-20',
                            '03-APR-20',
                            '03-APR-20',
                            '04-APR-20',
                            '04-APR-20',
                            '04-APR-20',
                            '05-APR-20',
                            '05-APR-20',
                            '05-APR-20',
                            '05-APR-20'],
         'attendance'    : ['F','T','T','T','T','T','F','T','T','T']
        }

data2 = {'student_id'    : [1,2,3,4],
         'school_id'     : [2,1,1,2],
         'grade'         : [5,4,3,4],
         'date_birth'    : ['03-APR-12',
                            '04-APR-13',
                            '05-APR-14',
                            '03-APR-13']
                        # '15-OCT-20',
                        # '29-OCT-20',
                        # '31-OCT-20']
        }

attendance  = pd.DataFrame(data1)
students    = pd.DataFrame(data2)

# %%
attendance['school_date'] = pd.to_datetime(attendance['school_date'])
students['date_birth'] = pd.to_datetime(students['date_birth'])
# Out:
# <ipython-input-8-5bca71635c74>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   attendance['school_date'] = pd.to_datetime(attendance['school_date'])
# <ipython-input-8-5bca71635c74>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   students['date_birth'] = pd.to_datetime(students['date_birth'])

# %%
attendance
# Out:
#    student_id school_date attendance
# 0           1  2020-04-03          F
# 1           2  2020-04-03          T
# 2           3  2020-04-03          T
# 3           1  2020-04-04          T
# 4           2  2020-04-04          T
# 5           3  2020-04-04          T
# 6           1  2020-04-05          F
# 7           2  2020-04-05          T
# 8           3  2020-04-05          T
# 9           4  2020-04-05          T

# %%
students
# Out:
#    student_id  school_id  grade date_birth
# 0           1          2      5 2012-04-03
# 1           2          1      4 2013-04-04
# 2           3          1      3 2014-04-05
# 3           4          2      4 2013-04-03

# %%
attendance['day'] = attendance['school_date'].dt.day
attendance['month'] = attendance['school_date'].dt.month
attendance = attendance[['student_id', 'day', 'month', 'attendance']]

# %%
attendance
# Out:
#    student_id  day  month attendance
# 0           1    3      4          F
# 1           2    3      4          T
# 2           3    3      4          T
# 3           1    4      4          T
# 4           2    4      4          T
# 5           3    4      4          T
# 6           1    5      4          F
# 7           2    5      4          T
# 8           3    5      4          T
# 9           4    5      4          T

# %%
students['day'] = students['date_birth'].dt.day
students['month'] = students['date_birth'].dt.month
student_births = students[['student_id', 'day', 'month']]

# %%
student_births
# Out:
#    student_id  day  month
# 0           1    3      4
# 1           2    4      4
# 2           3    5      4
# 3           4    3      4

# %%
attendance.set_index(['student_id', 'day', 'month'], inplace = True, drop = True)
student_births.set_index(['student_id', 'day', 'month'], inplace = True, drop = True)

# %%
attendance
# Out:
#                      attendance
# student_id day month
# 1          3   4              F
# 2          3   4              T
# 3          3   4              T
# 1          4   4              T
# 2          4   4              T
# 3          4   4              T
# 1          5   4              F
# 2          5   4              T
# 3          5   4              T
# 4          5   4              T

# %%
student_births
# Out:
# Empty DataFrame
# Columns: []
# Index: [(1, 3, 4), (2, 4, 4), (3, 5, 4), (4, 3, 4)]

# %%
birthday_attendance = pd.concat([attendance, student_births], axis = 1, join = 'inner')

# %%
birthday_attendance
# Out:
#                      attendance
# student_id day month
# 1          3   4              F
# 2          4   4              T
# 3          5   4              T

# %%
i = np.where(birthday_attendance['attendance'] == 'T', 1.0, 0.0).sum() / len(birthday_attendance)
d = {'rate' : [i]}
birthday_attendance_rate = pd.DataFrame(d)

# %%
birthday_attendance_rate.round(2)
# Out:
#    rate
# 0  0.67
